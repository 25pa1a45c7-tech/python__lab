# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c7-tech/python__lab/blob/main/program1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(2+3)
# Out:
# 5
