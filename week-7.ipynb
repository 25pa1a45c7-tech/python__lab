# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c7-tech/python__lab/blob/main/week-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10 # global variable
b = 20
print(a, b)
def func():
  c = 100 # local
  print(c)
  print(a, b)
func()
# Out:
# 10 20
# 100
# 10 20

# %%
a = 10 # golbal variable
b = 20 # golbal variable
print(a, b)
def func():
   c = 100 # local
   global a # to change the value of golbal variable
   a = 110
   print(c)
   print(a, b)
func()
print(a, b)
# Out:
# 10 20
# 100
# 110 20
# 110 20
